# %%
import schemdraw
from schemdraw import dsp
import schemdraw.elements as e

# %% [markdown]
# ## Biquad filter: Transposed Direct Form-II (TDF_II)

# %%
d = schemdraw.Drawing(fontsize = 12)
d.add(e.DOT_OPEN, label = 'Input', color = 'black')
L1 = d.add(dsp.LINE, d = 'right', l = 1, color = 'black')
d.add(dsp.LINE, d = 'right', l = 1, color = 'black')
d.add(dsp.AMP, toplabel = '$b_0$', color = 'black')
d.add(dsp.LINE, d = 'right', l = 0.75, color = 'black')
d.add(dsp.ARROWHEAD, d = 'right', color = 'black')
SUM0 = d.add(dsp.SUM, color = 'black')

d.add(dsp.LINE, xy = L1.end, d = 'down', l = 3, color = 'black')
L2 = d.add(dsp.LINE, d = 'right', l = 1, color = 'black')
d.add(dsp.AMP, toplabel = '$b_1$', color = 'black')
d.add(dsp.LINE, d = 'right', l = 0.75, color = 'black')
d.add(dsp.ARROWHEAD, d = 'right', color = 'black')
SUM1 = d.add(dsp.SUM, color = 'black')
d.add(dsp.LINE, d = 'up', xy = SUM1.N, l = 0.375, color = 'black')
d.add(dsp.BOX, label = '$z^{-1}$', color = 'black')
d.add(dsp.LINE, d = 'up', l = 0.625, color = 'black')
d.add(dsp.ARROWHEAD, d = 'up', color = 'black')

d.add(dsp.LINE, xy = L2.start, d = 'down', l = 3, color = 'black')
d.add(dsp.LINE, d = 'right', l = 1, color = 'black')
d.add(dsp.AMP, toplabel = '$b_2$', color = 'black')
d.add(dsp.LINE, d = 'right', l = 0.75, color = 'black')
d.add(dsp.ARROWHEAD, d = 'right', color = 'black')
SUM2 = d.add(dsp.SUM, color = 'black')
d.add(dsp.LINE, d = 'up', xy = SUM2.N, l = 0.375, color = 'black')
d.add(dsp.BOX, label = '$z^{-1}$', color = 'black')
d.add(dsp.LINE, d = 'up', l = 0.625, color = 'black')
d.add(dsp.ARROWHEAD, d = 'up', color = 'black')

Y = d.add(dsp.LINE, d = 'right', xy = SUM0.E, l = 2.5, color = 'black')
d.add(dsp.LINE, d = 'down', l = 3, color = 'black')
L3 = d.add(dsp.LINE, d = 'left', l = 1, color = 'black')
A1 = d.add(dsp.AMP, toplabel = '$-a_1$', color = 'black')
d.add(dsp.LINE, d = 'left', l = 0.75, color = 'black')
d.add(dsp.ARROWHEAD, d = 'left', color = 'black')

d.add(dsp.LINE, xy = L3.start, d = 'down', l = 3, color = 'black')
d.add(dsp.LINE, d = 'left', l = 1, color = 'black')
A2 = d.add(dsp.AMP, toplabel = '$-a_2$', color = 'black')
d.add(dsp.LINE, d = 'left', l = 0.75, color = 'black')
d.add(dsp.ARROWHEAD, d = 'left', color = 'black')

d.add(dsp.LINE, xy = Y.end, d = 'right', l = 1, color = 'black')
d.add(e.DOT_OPEN, label = 'Output', color = 'black')

d.draw()
#d.save('plots/TDF_II.svg')

# %% [markdown]
# # TDF_II with NL

# %%
d = schemdraw.Drawing(fontsize=12)
d.add (e.DOT_OPEN, label='Input', color='black')
L1 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_0$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM0 = d.add (dsp.SUM, color='black')

d.add (dsp.LINE, xy=L1.end, d='down', l=4.25, color='black')
L2 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_1$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM1 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM1.N, l=0.25, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='up', l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

d.add (dsp.LINE, xy=L2.start, d='down', l=3.25, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_2$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM2 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM2.N, l=0.25, color='black')
#d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='up', l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

Y = d.add (dsp.LINE, d='right', xy=SUM0.E, l=2.5, color='black')
d.add (dsp.LINE, d='down', l=4.25, color='black')
L3 = d.add (dsp.LINE, d='left', l=1, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_1$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=L3.start, d='down', l=3.25, color='black')
d.add (dsp.LINE, d='left', l=1, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_2$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=Y.end, d='right', l=1, color='black')
d.add (e.DOT_OPEN, label='Output', color='black')

d.draw()
#d.save('plots/NL_TDF_II_1_1.svg')

# %%
d = schemdraw.Drawing(fontsize=12)
d.add (e.DOT_OPEN, label='Input', color='black')
L1 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_0$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM0 = d.add (dsp.SUM, color='black')

d.add (dsp.LINE, xy=L1.end, d='down', l=3.25, color='black')
L2 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_1$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM1 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM1.N, l=0.25, color='black')
#d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='up', l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

d.add (dsp.LINE, xy=L2.start, d='down', l=4.25, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_2$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM2 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM2.N, l=0.25, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='up', l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

Y = d.add (dsp.LINE, d='right', xy=SUM0.E, l=2.5, color='black')
d.add (dsp.LINE, d='down', l=3.25, color='black')
L3 = d.add (dsp.LINE, d='left', l=1, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_1$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=L3.start, d='down', l=4.25, color='black')
d.add (dsp.LINE, d='left', l=1, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_2$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=Y.end, d='right', l=1, color='black')
d.add (e.DOT_OPEN, label='Output', color='black')

d.draw()
#d.save('plots/NL_TDF_II_1_2.svg')

# %%
d = schemdraw.Drawing(fontsize=12)
d.add (e.DOT_OPEN, label='Input', color='black')
L1 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_0$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM0 = d.add (dsp.SUM, color='black')

d.add (dsp.LINE, xy=L1.end, d='down', l=4.25, color='black')
L2 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_1$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM1 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM1.N, l=0.25, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='up', l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

d.add (dsp.LINE, xy=L2.start, d='down', l=4.25, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_2$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM2 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM2.N, l=0.25, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='up', l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

Y = d.add (dsp.LINE, d='right', xy=SUM0.E, l=2.5, color='black')
d.add (dsp.LINE, d='down', l=4.25, color='black')
L3 = d.add (dsp.LINE, d='left', l=1, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_1$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=L3.start, d='down', l=4.25, color='black')
d.add (dsp.LINE, d='left', l=1, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_2$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=Y.end, d='right', l=1, color='black')
d.add (e.DOT_OPEN, label='Output', color='black')

d.draw()
#d.save('plots/NL_TDF_II_2.svg')

# %% [markdown]
# # NLfeedback

# %%
d = schemdraw.Drawing(fontsize=12)
d.add (e.DOT_OPEN, label='Input', color='black')
L1 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_0$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM0 = d.add (dsp.SUM, color='black')

d.add (dsp.LINE, xy=L1.end, d='down', l=3, color='black')
L2 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_1$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM1 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM1.N, l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

d.add (dsp.LINE, xy=L2.start, d='down', l=3, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_2$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM2 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM2.N, l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

Y = d.add (dsp.LINE, d='right', xy=SUM0.E, l=3.5, color='black')
d.add (dsp.LINE, d='down', l=3, color='black')
L3 = d.add (dsp.LINE, d='left', l=0.5, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='left', l=0.5, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_1$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=L3.start, d='down', l=3, color='black')
d.add (dsp.LINE, d='left', l=1, color='black')
#d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='left', l=1, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_2$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=Y.end, d='right', l=1, color='black')
d.add (e.DOT_OPEN, label='Output', color='black')

d.draw()
#d.save('plots/NLfeedback_1_1.svg')

# %%
d = schemdraw.Drawing(fontsize=12)
d.add (e.DOT_OPEN, label='Input', color='black')
L1 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_0$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM0 = d.add (dsp.SUM, color='black')

d.add (dsp.LINE, xy=L1.end, d='down', l=3, color='black')
L2 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_1$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM1 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM1.N, l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

d.add (dsp.LINE, xy=L2.start, d='down', l=3, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_2$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM2 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM2.N, l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

Y = d.add (dsp.LINE, d='right', xy=SUM0.E, l=3.5, color='black')
d.add (dsp.LINE, d='down', l=3, color='black')
L3 = d.add (dsp.LINE, d='left', l=0.5, color='black')
#d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='left', l=1.5, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_1$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=L3.start, d='down', l=3, color='black')
d.add (dsp.LINE, d='left', l=0.5, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='left', l=0.5, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_2$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=Y.end, d='right', l=1, color='black')
d.add (e.DOT_OPEN, label='Output', color='black')

d.draw()
#d.save('plots/NLfeedback_1_2.svg')

# %%
d = schemdraw.Drawing(fontsize=12)
d.add (e.DOT_OPEN, label='Input', color='black')
L1 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_0$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM0 = d.add (dsp.SUM, color='black')

d.add (dsp.LINE, xy=L1.end, d='down', l=3, color='black')
L2 = d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_1$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM1 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM1.N, l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

d.add (dsp.LINE, xy=L2.start, d='down', l=3, color='black')
d.add (dsp.LINE, d='right', l=1, color='black')
d.add (dsp.AMP, toplabel='$b_2$', color='black')
d.add (dsp.LINE, d='right', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='right', color='black')
SUM2 = d.add (dsp.SUM, color='black')
d.add (dsp.LINE, d='up', xy=SUM2.N, l=0.375, color='black')
d.add (dsp.BOX, label='$z^{-1}$', color='black')
d.add (dsp.LINE, d='up', l=0.625, color='black')
d.add (dsp.ARROWHEAD, d='up', color='black')

Y = d.add (dsp.LINE, d='right', xy=SUM0.E, l=3.5, color='black')
d.add (dsp.LINE, d='down', l=3, color='black')
L3 = d.add (dsp.LINE, d='left', l=0.5, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='left', l=0.5, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_1$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=L3.start, d='down', l=3, color='black')
d.add (dsp.LINE, d='left', l=0.5, color='black')
d.add (dsp.BOX, label='NL', color='black')
d.add (dsp.LINE, d='left', l=0.5, color='black')
A1 = d.add (dsp.AMP, toplabel='$-a_2$', color='black')
d.add (dsp.LINE, d='left', l=0.75, color='black')
d.add (dsp.ARROWHEAD, d='left', color='black')

d.add (dsp.LINE, xy=Y.end, d='right', l=1, color='black')
d.add (e.DOT_OPEN, label='Output', color='black')

d.draw()
#d.save('plots/NLfeedback_2.svg')
